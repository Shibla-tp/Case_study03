# %% [markdown]
# ## **Importing Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## **Reading dataset**

# %%
df = pd.read_csv('/content/mobile_price_classification (2).csv')
df.head()
# Out:
#    battery_power  bluetooth  clock_speed  dual_sim  front_cam  4G  int_memory  \
# 0            842          0          2.2         0          1   0           7
# 1           1021          1          0.5         1          0   1          53
# 2            563          1          0.5         1          2   1          41
# 3            615          1          2.5         0          0   0          10
# 4           1821          1          1.2         0         13   1          44
#
#    m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.6        188        2  ...         20       756  2549     9     7
# 1    0.7        136        3  ...        905      1988  2631    17     3
# 2    0.9        145        5  ...       1263      1716  2603    11     2
# 3    0.8        131        6  ...       1216      1786  2769    16     8
# 4    0.6        141        2  ...       1208      1212  1411     8     2
#
#    talk_time  three_g  touch_screen  wifi  price_range
# 0         19        0             0     1            1
# 1          7        1             1     0            2
# 2          9        1             1     0            2
# 3         11        1             0     0            2
# 4         15        1             1     0            1
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   battery_power   2000 non-null   int64
#  1   bluetooth       2000 non-null   int64
#  2   clock_speed     2000 non-null   float64
#  3   dual_sim        2000 non-null   int64
#  4   front_cam       2000 non-null   int64
#  5   4G              2000 non-null   int64
#  6   int_memory      2000 non-null   int64
#  7   m_dep           2000 non-null   float64
#  8   mobile_wt       2000 non-null   int64
#  9   n_cores         2000 non-null   int64
#  10  primary_camera  2000 non-null   int64
#  11  px_height       2000 non-null   int64
#  12  px_width        2000 non-null   int64
#  13  ram             2000 non-null   int64
#  14  sc_h            2000 non-null   int64
#  15  sc_w            2000 non-null   int64
#  16  talk_time       2000 non-null   int64
#  17  three_g         2000 non-null   int64
#  18  touch_screen    2000 non-null   int64
#  19  wifi            2000 non-null   int64
#  20  price_range     2000 non-null   int64
# dtypes: float64(2), int64(19)
# memory usage: 328.2 KB

# %%
df.isna().sum()
# Out:
# battery_power     0
# bluetooth         0
# clock_speed       0
# dual_sim          0
# front_cam         0
# 4G                0
# int_memory        0
# m_dep             0
# mobile_wt         0
# n_cores           0
# primary_camera    0
# px_height         0
# px_width          0
# ram               0
# sc_h              0
# sc_w              0
# talk_time         0
# three_g           0
# touch_screen      0
# wifi              0
# price_range       0
# dtype: int64

# %%
df['price_range'].unique()
# Out:
# array([1, 2, 3, 0])

# %%
#visualization
plt.figure(figsize=(15,10))
sns.countplot(df['price_range'])
plt.title('Countplot of Price Ranges')
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.describe()
# Out:
#        battery_power  bluetooth  clock_speed     dual_sim    front_cam  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#                 4G   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# min       0.000000     2.000000     0.100000    80.000000     1.000000  ...
# 25%       0.000000    16.000000     0.200000   109.000000     3.000000  ...
# 50%       1.000000    32.000000     0.500000   141.000000     4.000000  ...
# 75%       1.000000    48.000000     0.800000   170.000000     7.000000  ...
# max       1.000000    64.000000     1.000000   200.000000     8.000000  ...
#
#          px_height     px_width          ram         sc_h         sc_w  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean    645.108000  1251.515500  2124.213000    12.306500     5.767000
# std     443.780811   432.199447  1084.732044     4.213245     4.356398
# min       0.000000   500.000000   256.000000     5.000000     0.000000
# 25%     282.750000   874.750000  1207.500000     9.000000     2.000000
# 50%     564.000000  1247.000000  2146.500000    12.000000     5.000000
# 75%     947.250000  1633.000000  3064.500000    16.000000     9.000000
# max    1960.000000  1998.000000  3998.000000    19.000000    18.000000
#
#          talk_time      three_g  touch_screen         wifi  price_range
# count  2000.000000  2000.000000   2000.000000  2000.000000  2000.000000
# mean     11.011000     0.761500      0.503000     0.507000     1.500000
# std       5.463955     0.426273      0.500116     0.500076     1.118314
# min       2.000000     0.000000      0.000000     0.000000     0.000000
# 25%       6.000000     1.000000      0.000000     0.000000     0.750000
# 50%      11.000000     1.000000      1.000000     1.000000     1.500000
# 75%      16.000000     1.000000      1.000000     1.000000     2.250000
# max      20.000000     1.000000      1.000000     1.000000     3.000000
#
# [8 rows x 21 columns]

# %% [markdown]
# ## **Standardising the features**

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
df['battery_power'] = sc.fit_transform(df[['battery_power']])
df['clock_speed'] = sc.fit_transform(df[['clock_speed']])
df['int_memory'] = sc.fit_transform(df[['int_memory']])
df['mobile_wt'] = sc.fit_transform(df[['mobile_wt']])
df['px_height'] = sc.fit_transform(df[['px_height']])
df['px_width'] = sc.fit_transform(df[['px_width']])
df['ram'] = sc.fit_transform(df[['ram']])

# %% [markdown]
# ## **Splitting Dataset**

# %%
data = df.drop('price_range',axis=1)
label = df.price_range

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.25, random_state=42)

# %%
X_train.shape
# Out:
# (1500, 20)

# %% [markdown]
# ## **Fitting ANN model**

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(10,activation='relu'))
model.add(Dense(4,activation='softmax'))

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.8952 - accuracy: 0.6793
# Epoch 2/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.8838 - accuracy: 0.6847
# Epoch 3/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.8684 - accuracy: 0.6900
# Epoch 4/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.8593 - accuracy: 0.7113
# Epoch 5/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.8493 - accuracy: 0.7060
# Epoch 6/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.8405 - accuracy: 0.7107
# Epoch 7/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.8277 - accuracy: 0.7020
# Epoch 8/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.8163 - accuracy: 0.7253
# Epoch 9/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.8081 - accuracy: 0.7160
# Epoch 10/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.7962 - accuracy: 0.7267
# Epoch 11/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.7862 - accuracy: 0.7400
# Epoch 12/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.7767 - accuracy: 0.7280
# Epoch 13/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.7682 - accuracy: 0.7540
# Epoch 14/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.7615 - accuracy: 0.7353
# Epoch 15/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.7505 - accuracy: 0.7527
# Epoch 16/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.7423 - accuracy: 0.7640
# Epoch 17/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.7347 - accuracy: 0.7520
# Epoch 18/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.7260 - accuracy: 0.7460
# Epoch 19/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.7209 - accuracy: 0.7493
# Epoch 20/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.7111 - accuracy: 0.7727
# Epoch 21/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.7021 - accuracy: 0.7740
# Epoch 22/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.6965 - accuracy: 0.7727
# Epoch 23/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.6867 - accuracy: 0.7780
# Epoch 24/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.6797 - accuracy: 0.7813
# Epoch 25/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.6715 - accuracy: 0.7847
# Epoch 26/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.6686 - accuracy: 0.7780
# Epoch 27/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.6645 - accuracy: 0.7873
# Epoch 28/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.6540 - accuracy: 0.7913
# Epoch 29/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.6475 - accuracy: 0.7953
# Epoch 30/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.6447 - accuracy: 0.7947
# Epoch 31/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.6396 - accuracy: 0.7907
# Epoch 32/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.6298 - accuracy: 0.8020
# Epoch 33/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.6244 - accuracy: 0.7980
# Epoch 34/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.6218 - accuracy: 0.7893
# Epoch 35/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.6126 - accuracy: 0.8133
# Epoch 36/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.6066 - accuracy: 0.8073
# Epoch 37/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.6004 - accuracy: 0.8100
# Epoch 38/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.5982 - accuracy: 0.8147
# Epoch 39/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.5920 - accuracy: 0.8113
# Epoch 40/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.5897 - accuracy: 0.8120
# Epoch 41/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.5858 - accuracy: 0.8133
# Epoch 42/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.5749 - accuracy: 0.8273
# Epoch 43/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.5747 - accuracy: 0.8153
# Epoch 44/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.5661 - accuracy: 0.8273
# Epoch 45/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.5639 - accuracy: 0.8220
# Epoch 46/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.5570 - accuracy: 0.8313
# Epoch 47/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.5542 - accuracy: 0.8233
# Epoch 48/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.5482 - accuracy: 0.8313
# Epoch 49/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.5430 - accuracy: 0.8340
# Epoch 50/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.5408 - accuracy: 0.8313
# Epoch 51/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.5383 - accuracy: 0.8267
# Epoch 52/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.5334 - accuracy: 0.8320
# Epoch 53/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.5288 - accuracy: 0.8320
# Epoch 54/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.5266 - accuracy: 0.8327
# Epoch 55/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.5201 - accuracy: 0.8407
# Epoch 56/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.5186 - accuracy: 0.8407
# Epoch 57/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.5126 - accuracy: 0.8420
# Epoch 58/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.5071 - accuracy: 0.8413
# Epoch 59/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.5054 - accuracy: 0.8467
# Epoch 60/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.5027 - accuracy: 0.8407
# Epoch 61/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.5026 - accuracy: 0.8380
# Epoch 62/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4940 - accuracy: 0.8413
# Epoch 63/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4910 - accuracy: 0.8533
# Epoch 64/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4909 - accuracy: 0.8353
# Epoch 65/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4846 - accuracy: 0.8487
# Epoch 66/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4838 - accuracy: 0.8467
# Epoch 67/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4777 - accuracy: 0.8547
# Epoch 68/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4750 - accuracy: 0.8513
# Epoch 69/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4697 - accuracy: 0.8560
# Epoch 70/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4708 - accuracy: 0.8540
# Epoch 71/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4676 - accuracy: 0.8387
# Epoch 72/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4610 - accuracy: 0.8607
# Epoch 73/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4570 - accuracy: 0.8620
# Epoch 74/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4568 - accuracy: 0.8520
# Epoch 75/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4511 - accuracy: 0.8600
# Epoch 76/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4528 - accuracy: 0.8567
# Epoch 77/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4478 - accuracy: 0.8573
# Epoch 78/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4434 - accuracy: 0.8587
# Epoch 79/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4443 - accuracy: 0.8680
# Epoch 80/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4396 - accuracy: 0.8620
# Epoch 81/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4359 - accuracy: 0.8573
# Epoch 82/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4338 - accuracy: 0.8640
# Epoch 83/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4312 - accuracy: 0.8580
# Epoch 84/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4292 - accuracy: 0.8607
# Epoch 85/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4316 - accuracy: 0.8600
# Epoch 86/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4233 - accuracy: 0.8647
# Epoch 87/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4231 - accuracy: 0.8667
# Epoch 88/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4159 - accuracy: 0.8687
# Epoch 89/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4144 - accuracy: 0.8680
# Epoch 90/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4119 - accuracy: 0.8673
# Epoch 91/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4098 - accuracy: 0.8727
# Epoch 92/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4054 - accuracy: 0.8700
# Epoch 93/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4044 - accuracy: 0.8693
# Epoch 94/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4012 - accuracy: 0.8760
# Epoch 95/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4006 - accuracy: 0.8693
# Epoch 96/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3992 - accuracy: 0.8767
# Epoch 97/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3955 - accuracy: 0.8773
# Epoch 98/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3953 - accuracy: 0.8707
# Epoch 99/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3906 - accuracy: 0.8747
# Epoch 100/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3882 - accuracy: 0.8713

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                210
#
#  dense_1 (Dense)             (None, 4)                 44
#
# =================================================================
# Total params: 254
# Trainable params: 254
# Non-trainable params: 0
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()
